# %%
from autogen import AssistantAgent, UserProxyAgent, config_list_from_json
import openai

# %%
openai.api_key = "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"

# %%
from autogen import AssistantAgent, UserProxyAgent, config_list_from_json
config_list = config_list_from_json(env_or_file="OAI_CONFIG_LIST")

assistant = AssistantAgent("assistant", 
                           llm_config={
                               "seed": 42,
                               "config_list": config_list})

user_proxy = UserProxyAgent("user_proxy",
                            max_consecutive_auto_reply=5, 
                            human_input_mode= "ALWAYS", 
                            code_execution_config={"work_dir": "coding"})

# %%
user_proxy.initiate_chat(assistant, message="Make me a simple waiter apps using python, in this waiter apps we can input the meal that we are ordering which in form of button, it will add to order, and calculate the total price for the meal.")
# Out:
# user_proxy (to assistant):
#
# Make me a simple waiter apps using python, in this waiter apps we can input the meal that we are ordering which in form of button, it will add to order, and calculate the total price for the meal.
#
# --------------------------------------------------------------------------------
# assistant (to user_proxy):
#
# To create a simple waiter app using Python you can use a command line interface application. For more advanced interfaces, you would need to create a web or desktop application using frameworks like Django or Qt.
#
# Assumptions:
#     1. The meal price is static and doesn't change
#     2. The available meals are predefined
#
# Here's how you might build a simple CLI (Command Line Interface) version of this:
#
# ```python
# # filename: waiter_app.py
#
# MEALS = {
#     'Chicken Soup': 10.00,
#     'Burger': 8.00,
#     'Pizza': 12.00,
#     'Salad': 7.50,
# }
#
# def view_menu():
#     print("Menu:")
# ...
